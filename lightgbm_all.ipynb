# %%
import os
import json
import pickle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import GridSearchCV
import lightgbm as lgb
from tqdm import tqdm_notebook as tqdm

from data_manager import DataManager
from utils import *

# %%
def stas_xgb(X_train, y_train, X_val, y_val=None):
    ytestxgb = np.zeros(X_val.shape[0])
    bgs = 10
    for bg in tqdm(range(bgs)):
        seed = bg + 1

        model = lgb.LGBMClassifier(
                learning_rate=0.05,
                max_depth=15 + np.random.randint(0,10),
                num_leaves=20 + np.random.randint(0,10),
                n_estimators=1000,
                objective='binary',
                n_jobs=12
            )
        model.fit(X_train, y_train, eval_set=(X_val, y_val), eval_metric='auc', early_stopping_rounds=100, verbose=False)
        
        ypredxgb = model.predict_proba(X_val)[:, 1]
        ytestxgb += ypredxgb
        
        if y_val is not None:
            print(bg, roc_auc_score(y_val, ytestxgb / (bg + 1.)), roc_auc_score(y_val, ypredxgb))
    
    ytestxgb /= bgs
    return ytestxgb

# %%
FEATURE_GENERATION = '5gen'

# %%
def prediction_for_one_city():
    dm = load_dm(FEATURE_GENERATION, CITY)
    X, X_test, y, block_ids, test_block_ids = dm.X_train, dm.X_test, dm.y_train, dm.train_block_ids, dm.test_block_ids
    in_train = block_ids['hours_since'] <= np.percentile(block_ids['hours_since'], 85)  #leave last 15% for validation
    X_train, y_train = X[in_train], y[in_train]
    X_val, y_val = X[~in_train], y[~in_train]

    train_data = lgb.Dataset(X_train, label=y_train)
    val_data = lgb.Dataset(X_val, label=y_val)
    param = {'metric': 'auc', 'num_trees': 1000, 'objective': 'binary', 'learning_rate': 0.02}
    bst = lgb.train(param, train_data, valid_sets=val_data, early_stopping_rounds=100)
    
    train_data = lgb.Dataset(X, label=y)
    param = {'metric': 'auc', 'num_trees': bst.best_iteration, 'objective': 'binary', 'learning_rate': 0.02}
    bst = lgb.train(param, train_data)
    
    y_pred = bst.predict(X_test)
    
    prediction_for_one_city = test_block_ids.copy()
    prediction_for_one_city["prediction"] = y_pred
    prediction_for_one_city.to_csv("./intermediate_data/lightgbm_{}.csv".format(CITY))
    prediction_for_one_city.head()

# %%
CITY = 'msk'
prediction_for_one_city()
# Out:
# /usr/local/lib/python3.5/dist-packages/lightgbm/engine.py:98: UserWarning: Found `num_trees` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's auc: 0.513457
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.513622
# [3]	valid_0's auc: 0.51497
# [4]	valid_0's auc: 0.514719
# [5]	valid_0's auc: 0.515842
# [6]	valid_0's auc: 0.515445
# [7]	valid_0's auc: 0.515544
# [8]	valid_0's auc: 0.516275
# [9]	valid_0's auc: 0.515625
# [10]	valid_0's auc: 0.5155
# [11]	valid_0's auc: 0.51571
# [12]	valid_0's auc: 0.516276
# [13]	valid_0's auc: 0.515794
# [14]	valid_0's auc: 0.530603
# [15]	valid_0's auc: 0.529786
# [16]	valid_0's auc: 0.623317
# [17]	valid_0's auc: 0.623409
# [18]	valid_0's auc: 0.6143
# [19]	valid_0's auc: 0.613254
# [20]	valid_0's auc: 0.615644
# [21]	valid_0's auc: 0.615969
# [22]	valid_0's auc: 0.619206
# [23]	valid_0's auc: 0.676299
# [24]	valid_0's auc: 0.698415
# [25]	valid_0's auc: 0.690419
# [26]	valid_0's auc: 0.705787
# [27]	valid_0's auc: 0.722677
# [28]	valid_0's auc: 0.729835
# [29]	valid_0's auc: 0.728376
# [30]	valid_0's auc: 0.729615
# [31]	valid_0's auc: 0.742824
# [32]	valid_0's auc: 0.751069
# [33]	valid_0's auc: 0.743975
# [34]	valid_0's auc: 0.739145
# [35]	valid_0's auc: 0.738095
# [36]	valid_0's auc: 0.739965
# [37]	valid_0's auc: 0.757473
# [38]	valid_0's auc: 0.769909
# [39]	valid_0's auc: 0.76829
# [40]	valid_0's auc: 0.768727
# [41]	valid_0's auc: 0.7753
# [42]	valid_0's auc: 0.772344
# [43]	valid_0's auc: 0.768905
# [44]	valid_0's auc: 0.765298
# [45]	valid_0's auc: 0.756629
# [46]	valid_0's auc: 0.75286
# [47]	valid_0's auc: 0.747904
# [48]	valid_0's auc: 0.746523
# [49]	valid_0's auc: 0.744578
# [50]	valid_0's auc: 0.752412
# [51]	valid_0's auc: 0.749088
# [52]	valid_0's auc: 0.752587
# [53]	valid_0's auc: 0.761613
# [54]	valid_0's auc: 0.763683
# [55]	valid_0's auc: 0.766462
# [56]	valid_0's auc: 0.76401
# [57]	valid_0's auc: 0.765978
# [58]	valid_0's auc: 0.763251
# [59]	valid_0's auc: 0.759299
# [60]	valid_0's auc: 0.756957
# [61]	valid_0's auc: 0.754368
# [62]	valid_0's auc: 0.760648
# [63]	valid_0's auc: 0.758466
# [64]	valid_0's auc: 0.755587
# [65]	valid_0's auc: 0.753435
# [66]	valid_0's auc: 0.750916
# [67]	valid_0's auc: 0.749466
# [68]	valid_0's auc: 0.75457
# [69]	valid_0's auc: 0.754399
# [70]	valid_0's auc: 0.75434
# [71]	valid_0's auc: 0.752566
# [72]	valid_0's auc: 0.76013
# [73]	valid_0's auc: 0.759355
# [74]	valid_0's auc: 0.758991
# [75]	valid_0's auc: 0.757239
# [76]	valid_0's auc: 0.755915
# [77]	valid_0's auc: 0.755271
# [78]	valid_0's auc: 0.752775
# [79]	valid_0's auc: 0.752371
# [80]	valid_0's auc: 0.752227
# [81]	valid_0's auc: 0.751756
# [82]	valid_0's auc: 0.749889
# [83]	valid_0's auc: 0.748291
# [84]	valid_0's auc: 0.745558
# [85]	valid_0's auc: 0.744476
# [86]	valid_0's auc: 0.744885
# [87]	valid_0's auc: 0.742986
# [88]	valid_0's auc: 0.742312
# [89]	valid_0's auc: 0.74053
# [90]	valid_0's auc: 0.738729
# [91]	valid_0's auc: 0.737988
# [92]	valid_0's auc: 0.736264
# [93]	valid_0's auc: 0.733452
# [94]	valid_0's auc: 0.731465
# [95]	valid_0's auc: 0.732026
# [96]	valid_0's auc: 0.730806
# [97]	valid_0's auc: 0.728889
# [98]	valid_0's auc: 0.727731
# [99]	valid_0's auc: 0.72584
# [100]	valid_0's auc: 0.724338
# [101]	valid_0's auc: 0.722214
# [102]	valid_0's auc: 0.721635
# [103]	valid_0's auc: 0.719543
# [104]	valid_0's auc: 0.717945
# [105]	valid_0's auc: 0.716608
# [106]	valid_0's auc: 0.715212
# [107]	valid_0's auc: 0.714759
# [108]	valid_0's auc: 0.712721
# [109]	valid_0's auc: 0.71218
# [110]	valid_0's auc: 0.712265
# [111]	valid_0's auc: 0.711402
# [112]	valid_0's auc: 0.710923
# [113]	valid_0's auc: 0.70834
# [114]	valid_0's auc: 0.707907
# [115]	valid_0's auc: 0.708298
# [116]	valid_0's auc: 0.707661
# [117]	valid_0's auc: 0.706118
# [118]	valid_0's auc: 0.706012
# [119]	valid_0's auc: 0.705862
# [120]	valid_0's auc: 0.705483
# [121]	valid_0's auc: 0.703854
# [122]	valid_0's auc: 0.702219
# [123]	valid_0's auc: 0.701406
# [124]	valid_0's auc: 0.699204
# [125]	valid_0's auc: 0.697301
# [126]	valid_0's auc: 0.697593
# [127]	valid_0's auc: 0.697363
# [128]	valid_0's auc: 0.698129
# [129]	valid_0's auc: 0.698735
# [130]	valid_0's auc: 0.697173
# [131]	valid_0's auc: 0.699772
# [132]	valid_0's auc: 0.699629
# [133]	valid_0's auc: 0.699198
# [134]	valid_0's auc: 0.700953
# [135]	valid_0's auc: 0.698929
# [136]	valid_0's auc: 0.696323
# [137]	valid_0's auc: 0.697924
# [138]	valid_0's auc: 0.695409
# [139]	valid_0's auc: 0.693417
# [140]	valid_0's auc: 0.695273
# [141]	valid_0's auc: 0.694955
# Early stopping, best iteration is:
# [41]	valid_0's auc: 0.7753
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-145dfe81c167> in <module>()
#       1 CITY = 'msk'
# ----> 2 prediction_for_one_city()
#
# <ipython-input-4-521c954bdd29> in prediction_for_one_city()
#      13     train_data = lgb.Dataset(X, label=y)
#      14     param = {'metric': 'auc', 'num_trees': bst.best_iteration, 'objective': 'binary', 'learning_rate': 0.02}
# ---> 15     bst = lgb.train(param, train_data)
#      16
#      17     y_pred = bst.predict(X_test)
#
# /usr/local/lib/python3.5/dist-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     176     """construct booster"""
#     177     try:
# --> 178         booster = Booster(params=params, train_set=train_set)
#     179         if is_valid_contain_train:
#     180             booster.set_train_data_name(train_data_name)
#
# /usr/local/lib/python3.5/dist-packages/lightgbm/basic.py in __init__(self, params, train_set, model_file, silent)
#    1263             self.handle = ctypes.c_void_p()
#    1264             _safe_call(_LIB.LGBM_BoosterCreate(
# -> 1265                 train_set.construct().handle,
#    1266                 c_str(params_str),
#    1267                 ctypes.byref(self.handle)))
#
# /usr/local/lib/python3.5/dist-packages/lightgbm/basic.py in construct(self)
#     817                                 weight=self.weight, group=self.group, predictor=self._predictor,
#     818                                 silent=self.silent, feature_name=self.feature_name,
# --> 819                                 categorical_feature=self.categorical_feature, params=self.params)
#     820             if self.free_raw_data:
#     821                 self.data = None
#
# /usr/local/lib/python3.5/dist-packages/lightgbm/basic.py in _lazy_init(self, data, label, max_bin, reference, weight, group, predictor, silent, feature_name, categorical_feature, params)
#     676             self.__init_from_csc(data, params_str, ref_dataset)
#     677         elif isinstance(data, np.ndarray):
# --> 678             self.__init_from_np2d(data, params_str, ref_dataset)
#     679         else:
#     680             try:
#
# /usr/local/lib/python3.5/dist-packages/lightgbm/basic.py in __init_from_np2d(self, mat, params_str, ref_dataset)
#     734             c_str(params_str),
#     735             ref_dataset,
# --> 736             ctypes.byref(self.handle)))
#     737
#     738     def __init_from_csr(self, csr, params_str, ref_dataset):
#
# KeyboardInterrupt:

# %%
CITY = 'spb'
prediction_for_one_city()

# %%
CITY = 'kazan'
prediction_for_one_city()

# %%
predictions = pd.concat(
    [pd.read_csv(fname,index_col=0) for fname in ("./intermediate_data/lightgbm_kazan.csv",
                                                  "./intermediate_data/lightgbm_spb.csv",
                                                  "./intermediate_data/lightgbm_msk.csv")],
    ignore_index=True
)
blocks = pd.read_csv("./data/raw/data/hackathon_tosubmit.tsv",sep='\t')
assert len(predictions) == len(blocks),"Predictions don't match blocks. Sumbit at your own risk."

merged = pd.merge(blocks,predictions,how='left',on=["sq_x","sq_y","hour_hash"])
assert not np.isnan(merged.prediction).any(), "some predictions are missing. Sumbit at your own risk."

# %%
merged[['id','prediction']].to_csv("lightgbm_submission.csv",sep=',',index=False,header=False)

# %%
# !head lightgbm_submission.csv
